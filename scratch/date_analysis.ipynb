# %%
import pandas as pd
import matplotlib.pyplot as plt
import statistics as stats
import numpy as np


df = pd.read_csv('possibility_counts.csv')

# %%
plt.plot([max(df['possibilities'][(i*364)-364:i*364]) for i in range(1,90)], '+')

# %%
plt.plot([stats.mean(df['possibilities'][(i*364)-364:i*364]) for i in range(1,90)], '+')

# %%
poscounts = { df['perf_num'][i*364]: df['possibilities'][(i*364)-364:i*364] for i in range(1,91) }

# %%
for perf_num in poscounts:
    print(str(perf_num) + ' | ' + str(max(poscount[perf_num])))
    if max(poscount[perf_num]) == 3:
        print(str(perf_num) + '-------------< ')
# Out:
# 10 | 9
# 11 | 6
# 12 | 8
# 13 | 4
# 14 | 4
# 15 | 10
# 16 | 7
# 17 | 4
# 18 | 16
# 19 | 9
# 20 | 10
# 21 | 7
# 22 | 6
# 23 | 6
# 24 | 6
# 25 | 7
# 26 | 5
# 27 | 9
# 28 | 9
# 29 | 4
# 30 | 9
# 31 | 7
# 32 | 5
# 33 | 8
# 34 | 6
# 35 | 5
# 36 | 9
# 37 | 9
# 38 | 4
# 39 | 5
# 40 | 10
# 41 | 10
# 42 | 5
# 43 | 4
# 44 | 6
# 45 | 18
# 46 | 18
# 47 | 4
# 48 | 6
# 49 | 4
# 50 | 9
# 51 | 9
# 52 | 5
# 53 | 4
# 54 | 9
# 55 | 9
# 56 | 6
# 57 | 5
# 58 | 5
# 59 | 3
# 59-------------<
# 60 | 8
# 61 | 8
# 62 | 5
# 63 | 8
# 64 | 6
# 65 | 5
# 66 | 6
# 67 | 6
# 68 | 5
# 69 | 5
# 70 | 6
# 71 | 6
# 72 | 12
# 73 | 12
# 74 | 4
# 75 | 7
# 76 | 7
# 77 | 4
# 78 | 6
# 79 | 6
# 80 | 6
# 81 | 7
# 82 | 9
# 83 | 3
# 83-------------<
# 84 | 4
# 85 | 5
# 86 | 4
# 87 | 4
# 88 | 4
# 89 | 4
# 90 | 16
# 91 | 24
# 92 | 7
# 93 | 5
# 94 | 4
# 95 | 4
# 96 | 5
# 97 | 4
# 98 | 3
# 98-------------<
# 99 | 8

# %%
print(len(np.where(poscounts[98] == 3)[0])/len(poscounts[98]))
print(len(np.where(poscounts[98] == 2)[0])/len(poscounts[98]))
print(len(np.where(poscounts[98] == 1)[0])/len(poscounts[98]))
plt.hist(poscounts[98])
# Out:
# 0.04395604395604396
# 0.2032967032967033
# 0.7527472527472527
# (array([274.,   0.,   0.,   0.,   0.,  74.,   0.,   0.,   0.,  16.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(poscounts[83])
# Out:
# (array([278.,   0.,   0.,   0.,   0.,  75.,   0.,   0.,   0.,  11.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(poscounts[59])
# Out:
# (array([272.,   0.,   0.,   0.,   0.,  78.,   0.,   0.,   0.,  14.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)
